# %%
#Import des librairies necessaire  a l'analyse des Data
from functools import reduce
import numpy as np
import pandas as pd
import matplotlib as plt
import Normalize_Carac as normalize
import datetime

def getData2018Merge():
    # Import des données des different csv de l'année 2018
    DataAccident2018usagers = pd.read_csv("données/2018/usagers-2018.csv",",",encoding='latin-1', low_memory=False)
    DataAccident2018lieux = pd.read_csv("données/2018/lieux-2018.csv",",",encoding='latin-1',low_memory=False)
    DataAccident2018vehicules = pd.read_csv("données/2018/vehicules-2018.csv",",",encoding='latin-1', low_memory=False)
    DataAccident2018caracteristiques = pd.read_csv("données/2018/caracteristiques-2018.csv",",",encoding='latin-1',low_memory=False)

    # Merge dataFrame
    Data2018Frame = [DataAccident2018caracteristiques, DataAccident2018lieux, DataAccident2018vehicules, DataAccident2018usagers]
    Data2018merge = reduce(lambda left,right: pd.merge(left,right,on='Num_Acc'), Data2018Frame)

    # Normalize data
    Data2018merge = normalize.normalise_carac(Data2018merge)

    # Correction for dupplicate data
    Data2018merge = Data2018merge[Data2018merge['num_veh_x'] == Data2018merge['num_veh_y']]

    # Affichage data
    Data2018merge.set_index(['Num_Acc','num_veh_x','num_veh_y'])
    return Data2018merge

# %%
DataAccident2017usagers = pd.read_csv("données/2017/usagers-2017.csv",",",encoding='latin-1', low_memory=False)
DataAccident2017lieux = pd.read_csv("données/2017/lieux-2017.csv",",",encoding='latin-1',low_memory=False)
DataAccident2017vehicules = pd.read_csv("données/2017/vehicules-2017.csv",",",encoding='latin-1', low_memory=False)
DataAccident2017caracteristiques = pd.read_csv("données/2017/caracteristiques-2017.csv",",",encoding='latin-1',low_memory=False)

# Merge dataFrame
Data2017Frame = [DataAccident2017caracteristiques, DataAccident2017lieux, DataAccident2017vehicules, DataAccident2017usagers]
Data2017merge = reduce(lambda left,right: pd.merge(left,right,on='Num_Acc'), Data2017Frame)

# Normalize data
Data2017merge = normalize.normalise_carac(Data2017merge)

# Correction for dupplicate data
Data2017merge = Data2017merge[Data2017merge['num_veh_x'] == Data2017merge['num_veh_y']]

# Affichage data
Data2017merge.set_index(['Num_Acc','num_veh_x','num_veh_y'])

def getData2017Merge():
    return Data2017merge
# Out:
#                                                                 lum  \
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01        Nuit avec éclairage public allumé
#                        B01        Nuit avec éclairage public allumé
#              A01       A01        Nuit avec éclairage public allumé
# 201700000002 A01       A01                               Plein jour
#              B01       B01                               Plein jour
# ...                                                             ...
# 201700060699 B01       B01                       Crépuscule ou aube
# 201700060700 A01       A01                               Plein jour
#              B01       B01                               Plein jour
#                        B01                               Plein jour
# 201700060701 A01       A01               Nuit sans éclairage public
#
#                                              agglo                int  \
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01        En agglomération  Hors Intersection
#                        B01        En agglomération  Hors Intersection
#              A01       A01        En agglomération  Hors Intersection
# 201700000002 A01       A01        En agglomération  Intersection en T
#              B01       B01        En agglomération  Intersection en T
# ...                                            ...                ...
# 201700060699 B01       B01        En agglomération  Hors Intersection
# 201700060700 A01       A01        En agglomération  Hors Intersection
#              B01       B01        En agglomération  Hors Intersection
#                        B01        En agglomération  Hors Intersection
# 201700060701 A01       A01        En agglomération  Hors Intersection
#
#                                       atm                           col  \
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01        Normale     Deux véhicules - frontale
#                        B01        Normale     Deux véhicules - frontale
#              A01       A01        Normale     Deux véhicules - frontale
# 201700000002 A01       A01        Normale  Deux véhicules – par le coté
#              B01       B01        Normale  Deux véhicules – par le coté
# ...                                   ...                           ...
# 201700060699 B01       B01        Normale  Deux véhicules – par le coté
# 201700060700 A01       A01        Normale  Deux véhicules – par le coté
#              B01       B01        Normale  Deux véhicules – par le coté
#                        B01        Normale  Deux véhicules – par le coté
# 201700060701 A01       A01        Normale               Autre collision
#
#                                                        adr        gps  \
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01                   RUE NATIONALE  Métropole
#                        B01                   RUE NATIONALE  Métropole
#              A01       A01                   RUE NATIONALE  Métropole
# 201700000002 A01       A01                5 RUE SONNEVILLE  Métropole
#              B01       B01                5 RUE SONNEVILLE  Métropole
# ...                                                    ...        ...
# 201700060699 B01       B01        1, TSOUNDZOU-ABDALLAH SO    Mayotte
# 201700060700 A01       A01         1, KAWENI-KAWENI NORD (    Mayotte
#              B01       B01         1, KAWENI-KAWENI NORD (    Mayotte
#                        B01         1, KAWENI-KAWENI NORD (    Mayotte
# 201700060701 A01       A01           TSOUNDZOU-STARA (RUE)    Mayotte
#
#                                         lat       long code_postal  ...  \
# Num_Acc      num_veh_x num_veh_y                                    ...
# 201700000001 B01       B01        5051326.0   292191.0       59477  ...
#                        B01        5051326.0   292191.0       59477  ...
#              A01       A01        5051326.0   292191.0       59477  ...
# 201700000002 A01       A01        5053611.0   295314.0       59005  ...
#              B01       B01        5053611.0   295314.0       59005  ...
# ...                                     ...        ...         ...  ...
# 201700060699 B01       B01        1280711.0  4520617.0       97611  ...
# 201700060700 A01       A01        1276210.0  4522609.0       97611  ...
#              B01       B01        1276210.0  4522609.0       97611  ...
#                        B01        1276210.0  4522609.0       97611  ...
# 201700060701 A01       A01        1281342.0  4520169.0       97611  ...
#
#                                         catu             grav      sexe  \
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01        Conducteur  Hospitalisation  Masculin
#                        B01          Passager  Hospitalisation   Féminin
#              A01       A01        Conducteur  Hospitalisation  Masculin
# 201700000002 A01       A01        Conducteur          Indemne  Masculin
#              B01       B01        Conducteur  Hospitalisation  Masculin
# ...                                      ...              ...       ...
# 201700060699 B01       B01        Conducteur          Indemne   Féminin
# 201700060700 A01       A01        Conducteur          Indemne   Féminin
#              B01       B01        Conducteur     Blessé léger  Masculin
#                        B01          Passager     Blessé léger   Féminin
# 201700060701 A01       A01        Conducteur     Blessé léger  Masculin
#
#                                                trajet  secu           locp  \
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01                     Autres  13.0  Pas de piéton
#                        B01                     Autres  11.0  Pas de piéton
#              A01       A01         Domicile - travail  13.0  Pas de piéton
# 201700000002 A01       A01                    Inconnu  11.0  Pas de piéton
#              B01       B01        Promenade - loisirs  22.0  Pas de piéton
# ...                                               ...   ...            ...
# 201700060699 B01       B01                     Autres  11.0  Pas de piéton
# 201700060700 A01       A01                     Autres  11.0  Pas de piéton
#              B01       B01                     Autres  21.0  Pas de piéton
#                        B01                     Autres  21.0  Pas de piéton
# 201700060701 A01       A01         Domicile - travail  21.0  Pas de piéton
#
#                                                          actp    etatp  \
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01        non renseigné ou sans objet  Inconnu
#                        B01        non renseigné ou sans objet  Inconnu
#              A01       A01        non renseigné ou sans objet  Inconnu
# 201700000002 A01       A01        non renseigné ou sans objet  Inconnu
#              B01       B01        non renseigné ou sans objet  Inconnu
# ...                                                       ...      ...
# 201700060699 B01       B01        non renseigné ou sans objet  Inconnu
# 201700060700 A01       A01        non renseigné ou sans objet  Inconnu
#              B01       B01        non renseigné ou sans objet  Inconnu
#                        B01        non renseigné ou sans objet  Inconnu
# 201700060701 A01       A01        non renseigné ou sans objet  Inconnu
#
#                                  an_nais       date
# Num_Acc      num_veh_x num_veh_y
# 201700000001 B01       B01        1968.0 2017-01-11
#                        B01        1973.0 2017-01-11
#              A01       A01        1967.0 2017-01-11
# 201700000002 A01       A01        1953.0 2017-02-13
#              B01       B01        1960.0 2017-02-13
# ...                                  ...        ...
# 201700060699 B01       B01        1974.0 2017-11-26
# 201700060700 A01       A01        1987.0 2017-11-28
#              B01       B01        1991.0 2017-11-28
#                        B01        1990.0 2017-11-28
# 201700060701 A01       A01        1992.0 2017-11-30
#
# [136021 rows x 45 columns]
